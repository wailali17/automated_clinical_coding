# %%
import pandas as pd
import os
project_dir = os.getcwd()

# %%
icd = pd.read_csv(f"{project_dir}/original_data/hosp/d_icd_diagnoses.csv.gz")
icd.head()
# Out:
#   icd_code  icd_version                             long_title
# 0     0010            9         Cholera due to vibrio cholerae
# 1     0011            9  Cholera due to vibrio cholerae el tor
# 2     0019            9                   Cholera, unspecified
# 3     0020            9                          Typhoid fever
# 4     0021            9                    Paratyphoid fever A

# %%
diagnoses = pd.read_csv(f"{project_dir}/original_data/hosp/diagnoses_icd.csv.gz")
diagnoses.head()
# Out:
#    subject_id   hadm_id  seq_num icd_code  icd_version
# 0    10000032  22595853        1     5723            9
# 1    10000032  22595853        2    78959            9
# 2    10000032  22595853        3     5715            9
# 3    10000032  22595853        4    07070            9
# 4    10000032  22595853        5      496            9

# %%
import simple_icd_10_cm as cm

icd = icd[icd.icd_version == 10]
for i, row in icd.iterrows():
    if cm.is_valid_item(row.icd_code):
        chapter = cm.get_ancestors(row.icd_code)[-1]
        chapter_description = cm.get_description(chapter)
        icd.loc[i, "chapter"] = chapter + " - " + chapter_description
        block = cm.get_ancestors(row.icd_code)[-2]
        block_description = cm.get_description(block)
        icd.loc[i, "block"] = block_description
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 8
#       6 chapter = cm.get_ancestors(row.icd_code)[-1]
#       7 chapter_description = cm.get_description(chapter)
# ----> 8 icd.loc[i, "chapter"] = chapter + " - " + chapter_description
#       9 block = cm.get_ancestors(row.icd_code)[-2]
#      10 block_description = cm.get_description(block)
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
#    1944     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\indexing.py:2035, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    2032 else:
#    2033     # scalar value
#    2034     for loc in ilocs:
# -> 2035         self._setitem_single_column(loc, value, pi)
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\indexing.py:2175, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2165     if dtype == np.void:
#    2166         # This means we're expanding, with multiple columns, e.g.
#    2167         #     df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
#    (...)
#    2170         # Here, we replace those temporary `np.void` columns with
#    2171         # columns of the appropriate dtype, based on `value`.
#    2172         self.obj.iloc[:, loc] = construct_1d_array_from_inferred_fill_value(
#    2173             value, len(self.obj)
#    2174         )
# -> 2175     self.obj._mgr.column_setitem(loc, plane_indexer, value)
#    2177 self.obj._clear_item_cache()
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\internals\managers.py:1337, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1335     col_mgr.setitem_inplace(idx, value)
#    1336 else:
# -> 1337     new_mgr = col_mgr.setitem((idx,), value)
#    1338     self.iset(loc, new_mgr._block.values, inplace=True)
#    1340 if needs_to_warn:
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\internals\managers.py:415, in BaseBlockManager.setitem(self, indexer, value, warn)
#     411     # No need to split if we either set all columns or on a single block
#     412     # manager
#     413     self = self.copy()
# --> 415 return self.apply("setitem", indexer=indexer, value=value)
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\internals\blocks.py:1424, in Block.setitem(self, indexer, value, using_cow)
#    1421         casted = setitem_datetimelike_compat(values, len(vi), casted)
#    1423 self = self._maybe_copy(using_cow, inplace=True)
# -> 1424 values = cast(np.ndarray, self.values.T)
#    1425 if isinstance(casted, np.ndarray) and casted.ndim == 1 and len(casted) == 1:
#    1426     # NumPy 1.25 deprecation: https://github.com/numpy/numpy/pull/10615
#    1427     casted = casted[0, ...]
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\typing.py:2182, in cast(typ, val)
#    2178                 cls.__non_callable_proto_members__.add(attr)
#    2179     return cls
# -> 2182 def cast(typ, val):
#    2183     """Cast a value to a type.
#    2184
#    2185     This returns the value unchanged.  To the type checker this
#    (...)
#    2188     to be as fast as possible).
#    2189     """
#    2190     return val
#
# KeyboardInterrupt:

# %%
icd.head()
# Out:
#       icd_code  icd_version  \
# 12238      A00           10
# 12239     A000           10
# 12240     A001           10
# 12241     A009           10
# 12242      A01           10
#
#                                               long_title  \
# 12238                                            Cholera
# 12239  Cholera due to Vibrio cholerae 01, biovar chol...
# 12240    Cholera due to Vibrio cholerae 01, biovar eltor
# 12241                               Cholera, unspecified
# 12242                     Typhoid and paratyphoid fevers
#
#                                                  chapter  \
# 12238  1 - Certain infectious and parasitic diseases ...
# 12239  1 - Certain infectious and parasitic diseases ...
# 12240  1 - Certain infectious and parasitic diseases ...
# 12241  1 - Certain infectious and parasitic diseases ...
# 12242  1 - Certain infectious and parasitic diseases ...
#
#                                           block
# 12238  Intestinal infectious diseases (A00-A09)
# 12239  Intestinal infectious diseases (A00-A09)
# 12240  Intestinal infectious diseases (A00-A09)
# 12241  Intestinal infectious diseases (A00-A09)
# 12242  Intestinal infectious diseases (A00-A09)

# %%
    icd_code_count = (
        diagnoses[diagnoses.icd_version == 10]
        .groupby("icd_code")
        .agg({"subject_id":"count"})
        .sort_values("subject_id", ascending=False)
        .reset_index()
        .rename(columns={"subject_id":"icd_occurence"})
        )
    
    # Obtaining the ICD codes that occur at least 5k times in the datasets when assigned to patients
    # We then subset the dataset to contain those chosen ICD codes.
    # In this instance we only want 5 ICD codes.
    subjects = []
    while len(subjects) < 1000:
        # logging.info("Re-sampling due to small sample set")
        chosen_codes = icd_code_count[(icd_code_count.icd_occurence > 5000) & (icd_code_count.icd_code.str.len() >= 4)].sample(5).icd_code.tolist()
        df = icd[icd.icd_code.isin(chosen_codes)].merge(diagnoses, how="left", on=["icd_code", "icd_version"])
        subjects = df.subject_id.unique().tolist()

# %%
len(subjects)
# Out:
# 29283

# %%
# emr = pd.DataFrame()
# for chunk in pd.read_csv(f"{project_dir}/original_data/hosp/emar.csv.gz", chunksize=100):
#     subbed = chunk[chunk.subject_id.isin(subjects)]
#     emr =  emr._append(subbed[~subbed.hadm_id.isna()])
emr.head(2)
# Out:
#      subject_id     hadm_id      emar_id  emar_seq       poe_id  pharmacy_id  \
# 190    10000117  27988844.0  10000117-20        20  10000117-53          NaN
# 191    10000117  27988844.0  10000117-21        21  10000117-74    6506219.0
#
#     enter_provider_id            charttime                      medication  \
# 190               NaN  2183-09-18 12:35:00  Influenza Vaccine Quadrivalent
# 191               NaN  2183-09-18 22:23:00     Sodium Chloride 0.9%  Flush
#
#      event_txt         scheduletime            storetime
# 190  Hold Dose  2183-09-18 12:35:00  2183-09-18 12:39:00
# 191    Flushed  2183-09-18 22:23:00  2183-09-18 22:23:00

# %%
    labitems = pd.read_csv(f"{project_dir}/original_data/hosp/d_labitems.csv.gz")
    labevents = pd.DataFrame()
    for idx, chunk in enumerate(pd.read_csv(f"{project_dir}/original_data/hosp/labevents.csv.gz", chunksize=100, low_memory=False)):
        subbed = chunk[chunk["subject_id"].isin(subjects)][["labevent_id", "subject_id", "hadm_id", "itemid", "flag", "priority", "comments"]]
        if len(subbed) > 0:
            subbed = (
                subbed
                .merge(labitems, on="itemid", how="left")
                )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 4
#       2 labevents = pd.DataFrame()
#       3 for idx, chunk in enumerate(pd.read_csv(f"{project_dir}/original_data/hosp/labevents.csv.gz", chunksize=100, low_memory=False)):
# ----> 4     subbed = chunk[chunk["subject_id"].isin(subjects)][["labevent_id", "subject_id", "hadm_id", "itemid", "flag", "priority", "comments"]]
#       5     if len(subbed) > 0:
#       6         subbed = (
#       7             subbed
#       8             .merge(labitems, on="itemid", how="left")
#       9             )
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\series.py:5559, in Series.isin(self, values)
#    5486 def isin(self, values) -> Series:
#    5487     """
#    5488     Whether elements in Series are contained in `values`.
#    5489
#    (...)
#    5557     dtype: bool
#    5558     """
# -> 5559     result = algorithms.isin(self._values, values)
#    5560     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5561         self, method="isin"
#    5562     )
#
# File c:\Users\waila\anaconda3\envs\MSC_ENV\Lib\site-packages\pandas\core\algorithms.py:545, in isin(comps, values)
#     542     comps_array = comps_array.astype(common, copy=False)
#     543     f = htable.ismember
# --> 545 return f(comps_array, values)
#
# KeyboardInterrupt:

# %%
    admission = pd.read_csv(f"{project_dir}/original_data/hosp/admissions.csv.gz")

# %%
admission.head()
# Out:
#    subject_id   hadm_id            admittime            dischtime deathtime  \
# 0    10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00       NaN
# 1    10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00       NaN
# 2    10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00       NaN
# 3    10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00       NaN
# 4    10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00       NaN
#
#    admission_type admit_provider_id      admission_location  \
# 0          URGENT            P874LG  TRANSFER FROM HOSPITAL
# 1        EW EMER.            P09Q6Y          EMERGENCY ROOM
# 2        EW EMER.            P60CC5          EMERGENCY ROOM
# 3        EW EMER.            P30KEH          EMERGENCY ROOM
# 4  EU OBSERVATION            P51VDL          EMERGENCY ROOM
#
#   discharge_location insurance language marital_status   race  \
# 0               HOME     Other  ENGLISH        WIDOWED  WHITE
# 1               HOME  Medicaid  ENGLISH        WIDOWED  WHITE
# 2            HOSPICE  Medicaid  ENGLISH        WIDOWED  WHITE
# 3               HOME  Medicaid  ENGLISH        WIDOWED  WHITE
# 4                NaN     Other  ENGLISH         SINGLE  WHITE
#
#              edregtime            edouttime  hospital_expire_flag
# 0  2180-05-06 19:17:00  2180-05-06 23:30:00                     0
# 1  2180-06-26 15:54:00  2180-06-26 21:31:00                     0
# 2  2180-08-05 20:58:00  2180-08-06 01:44:00                     0
# 3  2180-07-23 05:54:00  2180-07-23 14:00:00                     0
# 4  2160-03-03 21:55:00  2160-03-04 06:26:00                     0
